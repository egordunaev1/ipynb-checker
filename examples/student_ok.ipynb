# %% [markdown]
# # Задание 1
# <!-- TASK:01 START -->

# %%
def add_one(x):
    return x + 1

# %% [markdown]
# <!-- TASK:01 END -->
# *Конец решения*

# %% [markdown]
# # Задание 2
# <!-- TASK:02 START -->

# %%
def mean_age(df):
    return sum(df["age"]) / len(df)

# %% [markdown]
# <!-- TASK:02 END -->
# *Конец решения*
